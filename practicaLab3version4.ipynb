# %%
import pandas as pd
import matplotlib as plt
import seaborn as nsn

# %%
df=pd.read_csv ("https://raw.githubusercontent.com/fvillena/biocompu/2024/data/obesity.csv")

# %%
df.sample(3)
# Out:
#       Gender        Age family_history_with_overweight FAVC      FCVC  NCP  \
# 522   Female  20.254534                             no  yes  2.392665  1.0
# 1160    Male  21.997335                            yes  yes  2.000000  3.0
# 1885  Female  26.000000                            yes  yes  3.000000  3.0
#
#             CAEC SMOKE      CH2O SCC       FAF       TUE       CALC  \
# 522   Frequently    no  1.000000  no  0.000000  0.738269  Sometimes
# 1160   Sometimes    no  2.000000  no  0.527341  2.000000         no
# 1885   Sometimes    no  2.625537  no  0.000000  0.162494  Sometimes
#
#                      MTRANS        BMI
# 522   Public_Transportation  16.776318
# 1160  Public_Transportation  29.384757
# 1885  Public_Transportation  41.464342

# %%
from sklearn.preprocessing import LabelEncoder

# %%
df.Gender
le = LabelEncoder()

print(df.Gender.drop_duplicates())

le.fit(df.Gender.drop_duplicates()) 
df.Gender = le.transform(df.Gender)
df.Gender
# Out:
# 0    0
# 2    1
# Name: Gender, dtype: int64
# 0       0
# 1       0
# 2       1
# 3       1
# 4       1
#        ..
# 2106    0
# 2107    0
# 2108    0
# 2109    0
# 2110    0
# Name: Gender, Length: 2111, dtype: int64

# %%
le.fit(df.FAVC.drop_duplicates()) 
df.FAVC = le.transform(df.FAVC)
df.FAVC
# Out:
# 0       0
# 1       0
# 2       0
# 3       0
# 4       0
#        ..
# 2106    1
# 2107    1
# 2108    1
# 2109    1
# 2110    1
# Name: FAVC, Length: 2111, dtype: int64

# %%
le.fit(df.SMOKE.drop_duplicates()) 
df.SMOKE = le.transform(df.SMOKE)
df.SMOKE
# Out:
# 0       0
# 1       1
# 2       0
# 3       0
# 4       0
#        ..
# 2106    0
# 2107    0
# 2108    0
# 2109    0
# 2110    0
# Name: SMOKE, Length: 2111, dtype: int64

# %%
le.fit(df.SCC.drop_duplicates()) 
df.SCC= le.transform(df.SCC	)
df.SCC
# Out:
# 0       0
# 1       1
# 2       0
# 3       0
# 4       0
#        ..
# 2106    0
# 2107    0
# 2108    0
# 2109    0
# 2110    0
# Name: SCC, Length: 2111, dtype: int64

# %%
le.fit(df.family_history_with_overweight.drop_duplicates()) 
df.family_history_with_overweight= le.transform(df.family_history_with_overweight)
df.family_history_with_overweight
# Out:
# 0       1
# 1       1
# 2       1
# 3       0
# 4       0
#        ..
# 2106    1
# 2107    1
# 2108    1
# 2109    1
# 2110    1
# Name: family_history_with_overweight, Length: 2111, dtype: int64

# %%
le.fit(df.CAEC.drop_duplicates()) 
df.CAEC= le.transform(df.CAEC)
df.CAEC
# Out:
# 0       2
# 1       2
# 2       2
# 3       2
# 4       2
#        ..
# 2106    2
# 2107    2
# 2108    2
# 2109    2
# 2110    2
# Name: CAEC, Length: 2111, dtype: int64

# %%
le.fit(df.CALC	.drop_duplicates()) 
df.CALC	= le.transform(df.CALC)
df.CALC
# Out:
# 0       3
# 1       2
# 2       1
# 3       1
# 4       2
#        ..
# 2106    2
# 2107    2
# 2108    2
# 2109    2
# 2110    2
# Name: CALC, Length: 2111, dtype: int64

# %%
le.fit(df.MTRANS	.drop_duplicates()) 
df.MTRANS	= le.transform(df.MTRANS)
df.MTRANS
# Out:
# 0       3
# 1       3
# 2       3
# 3       4
# 4       3
#        ..
# 2106    3
# 2107    3
# 2108    3
# 2109    3
# 2110    3
# Name: MTRANS, Length: 2111, dtype: int64

# %%
df
# Out:
#       Gender        Age  family_history_with_overweight  FAVC  FCVC  NCP  \
# 0          0  21.000000                               1     0   2.0  3.0
# 1          0  21.000000                               1     0   3.0  3.0
# 2          1  23.000000                               1     0   2.0  3.0
# 3          1  27.000000                               0     0   3.0  3.0
# 4          1  22.000000                               0     0   2.0  1.0
# ...      ...        ...                             ...   ...   ...  ...
# 2106       0  20.976842                               1     1   3.0  3.0
# 2107       0  21.982942                               1     1   3.0  3.0
# 2108       0  22.524036                               1     1   3.0  3.0
# 2109       0  24.361936                               1     1   3.0  3.0
# 2110       0  23.664709                               1     1   3.0  3.0
#
#       CAEC  SMOKE      CH2O  SCC       FAF       TUE  CALC  MTRANS        BMI
# 0        2      0  2.000000    0  0.000000  1.000000     3       3  24.386526
# 1        2      1  3.000000    1  3.000000  0.000000     2       3  24.238227
# 2        2      0  2.000000    0  2.000000  1.000000     1       3  23.765432
# 3        2      0  2.000000    0  2.000000  0.000000     1       4  26.851852
# 4        2      0  2.000000    0  0.000000  0.000000     2       3  28.342381
# ...    ...    ...       ...  ...       ...       ...   ...     ...        ...
# 2106     2      0  1.728139    0  1.676269  0.906247     2       3  44.901475
# 2107     2      0  2.005130    0  1.341390  0.599270     2       3  43.741923
# 2108     2      0  2.054193    0  1.414209  0.646288     2       3  43.543817
# 2109     2      0  2.852339    0  1.139107  0.586035     2       3  44.071535
# 2110     2      0  2.863513    0  1.026452  0.714137     2       3  44.144338
#
# [2111 rows x 15 columns]

# %%
df.corr()['BMI'].sort_values()
# Out:
# SCC                              -0.184286
# FAF                              -0.177537
# CALC                             -0.169805
# TUE                              -0.099720
# Gender                           -0.053035
# SMOKE                            -0.000819
# MTRANS                            0.022061
# NCP                               0.039969
# CH2O                              0.144200
# Age                               0.244163
# FAVC                              0.246097
# FCVC                              0.263651
# CAEC                              0.313278
# family_history_with_overweight    0.483508
# BMI                               1.000000
# Name: BMI, dtype: float64

# %%
# se puede ver que la variable mas relacionada con el indice de masa muscular BMI es la historia de sobrepeso en la familia

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
f, ax = plt.subplots(figsize=(10, 8))
corr = df.corr()
sns.heatmap(corr, mask=np.zeros_like(corr, dtype=bool), cmap=sns.diverging_palette(240,10,as_cmap=True),
            square=True, ax=ax)
# Out:
# <Axes: >

# %%
f= plt.figure(figsize=(12,5))

ax=f.add_subplot(121)
sns.distplot(df[(df.family_history_with_overweight == 1)]["BMI"],color='c',ax=ax)
ax.set_title('Distribution of BMI for family_history_with_overweight')

ax=f.add_subplot(122)
sns.distplot(df[(df.family_history_with_overweight == 0)]['BMI'],color='b',ax=ax)
ax.set_title('Distribution of BMI for non-family_history_with_overweight')
# Out:
# /tmp/ipykernel_5916/416410121.py:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df[(df.family_history_with_overweight == 1)]["BMI"],color='c',ax=ax)
# /tmp/ipykernel_5916/416410121.py:8: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df[(df.family_history_with_overweight == 0)]['BMI'],color='b',ax=ax)
# Text(0.5, 1.0, 'Distribution of BMI for non-family_history_with_overweight')

# %%
sns.catplot(x="family_history_with_overweight", kind="count",hue = 'Gender', palette="pink", data=df)

# %%
plt.figure(figsize=(12,5))
plt.title("Box plot for BMI for women ")
sns.boxplot(y="family_history_with_overweight", x="BMI", data =  df[(df.Gender == 0)] , orient="h", palette = 'magma')
# Out:
# /tmp/ipykernel_5916/3446268006.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(y="family_history_with_overweight", x="BMI", data =  df[(df.Gender == 0)] , orient="h", palette = 'magma')
# <Axes: title={'center': 'Box plot for BMI for women '}, xlabel='BMI', ylabel='family_history_with_overweight'>

# %%
plt.figure(figsize=(12,5))
plt.title("Box plot for BMI of men")
sns.boxplot(y="family_history_with_overweight", x="BMI", data =df[(df.Gender ==1)] , orient="h", palette = 'rainbow')
# Out:
# /tmp/ipykernel_5916/125740588.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(y="family_history_with_overweight", x="BMI", data =df[(df.Gender ==1)] , orient="h", palette = 'rainbow')
# <Axes: title={'center': 'Box plot for BMI of men'}, xlabel='BMI', ylabel='family_history_with_overweight'>

# %%
plt.figure(figsize=(12,5))
plt.title("Box plot for BMI 21 years old family_history_with_overweight")
sns.boxplot(y="family_history_with_overweight", x="BMI", data = df[(df.Age == 21)] , orient="h", palette = 'pink')
# Out:
# /tmp/ipykernel_5916/3608753301.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(y="family_history_with_overweight", x="BMI", data = df[(df.Age == 21)] , orient="h", palette = 'pink')
# <Axes: title={'center': 'Box plot for BMI 21 years old family_history_with_overweight'}, xlabel='BMI', ylabel='family_history_with_overweight'>

# %%
X = df.drop(['BMI'], axis = 1)
y = df.BMI

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state = 123)

# %%
from sklearn.linear_model import LinearRegression

lr = LinearRegression().fit(X_train, y_train)

# %%
lr_vil = pd.DataFrame(lr.coef_,columns=["value"]) # Guardamos en un dataframe los coeficientes
lr_vil.index = df.columns[:-1]
lr_vil
# Out:
#                                    value
# Gender                         -0.469805
# Age                             0.268256
# family_history_with_overweight  7.474711
# FAVC                            3.304973
# FCVC                            3.604234
# NCP                             0.464630
# CAEC                            3.399215
# SMOKE                          -0.576488
# CH2O                            0.486005
# SCC                            -1.832618
# FAF                            -0.755776
# TUE                            -0.843575
# CALC                           -1.613143
# MTRANS                          1.252619

# %%
y_pred = lr.predict(X_test)

# %%
from sklearn.metrics import mean_absolute_error,mean_squared_error, r2_score
 
def compute_metrics(y_true, y_pred):
    """
    Esta función recibe un arreglo de valores reales y predichos para 
    retornar un diccionario con una serie de métricas de regresión
    """
    return {
        'mae': mean_absolute_error(y_true, y_pred),
        'rmse': mean_squared_error(y_true, y_pred) ** 0.5,
        'r2': r2_score(y_true, y_pred)
    }

# %%
lr_regression_report = compute_metrics(y_test, y_pred)

# %%
lr_regression_report
# Out:
# {'mae': np.float64(4.8533621078993905),
#  'rmse': np.float64(5.962436260915067),
#  'r2': 0.47139055806266783}

# %%
from sklearn.model_selection import GridSearchCV

# %%
from sklearn.ensemble import RandomForestRegressor

# %%
param_grid = {
    'n_estimators': [50, 100],       # Número de árboles en el bosque
    'criterion': ['squared_error', 'absolute_error'],         # Criterio para medir la calidad de la división de nodos ('mse': error cuadrático medio, 'mae': error absoluto medio)
    'max_depth': [10, 20],     # Profundidad máxima de los árboles (None: sin límite de profundidad)
    'min_samples_split': [2, 5, 10],     # Número mínimo de muestras requeridas para dividir un nodo interno
    'min_samples_leaf': [1, 2]        # Número mínimo de muestras requeridas en un nodo hoja
}

# %%
rf = RandomForestRegressor()

# %%
grid_search = GridSearchCV(rf, param_grid, cv=5, scoring='r2')
grid_search.fit(X, y)
# Out:
# GridSearchCV(cv=5, estimator=RandomForestRegressor(),
#              param_grid={'criterion': ['squared_error', 'absolute_error'],
#                          'max_depth': [10, 20], 'min_samples_leaf': [1, 2],
#                          'min_samples_split': [2, 5, 10],
#                          'n_estimators': [50, 100]},
#              scoring='r2')

# %%
# Acceder a los resultados
best_params = grid_search.best_params_
best_score = grid_search.best_score_
best_model = grid_search.best_estimator_
cv_results = grid_search.cv_results_

# %%
best_params
# Out:
# {'criterion': 'squared_error',
#  'max_depth': 20,
#  'min_samples_leaf': 1,
#  'min_samples_split': 2,
#  'n_estimators': 100}

# %%
df_cv_results = pd.DataFrame(cv_results)

# %%
df_cv_results.head()
# Out:
#    mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0       0.223403      0.009553         0.005452        0.000280
# 1       0.492984      0.042045         0.013462        0.007309
# 2       0.214931      0.009755         0.005349        0.000330
# 3       0.428322      0.016224         0.008805        0.001031
# 4       0.230219      0.016073         0.005235        0.000161
#
#   param_criterion  param_max_depth  param_min_samples_leaf  \
# 0   squared_error               10                       1
# 1   squared_error               10                       1
# 2   squared_error               10                       1
# 3   squared_error               10                       1
# 4   squared_error               10                       1
#
#    param_min_samples_split  param_n_estimators  \
# 0                        2                  50
# 1                        2                 100
# 2                        5                  50
# 3                        5                 100
# 4                       10                  50
#
#                                               params  split0_test_score  \
# 0  {'criterion': 'squared_error', 'max_depth': 10...          -0.205873
# 1  {'criterion': 'squared_error', 'max_depth': 10...          -0.216112
# 2  {'criterion': 'squared_error', 'max_depth': 10...          -0.217139
# 3  {'criterion': 'squared_error', 'max_depth': 10...          -0.251851
# 4  {'criterion': 'squared_error', 'max_depth': 10...          -0.193089
#
#    split1_test_score  split2_test_score  split3_test_score  split4_test_score  \
# 0          -0.572479          -2.546422          -1.392743          -5.939138
# 1          -0.563076          -2.474800          -1.253528          -5.388784
# 2          -0.497977          -2.601397          -1.322265          -5.854848
# 3          -0.600724          -2.574241          -1.308085          -5.579931
# 4          -0.600672          -2.676486          -1.529732          -6.233543
#
#    mean_test_score  std_test_score  rank_test_score
# 0        -2.131331        2.066621               22
# 1        -1.979260        1.871436               10
# 2        -2.098725        2.052646               19
# 3        -2.062966        1.929693               17
# 4        -2.246704        2.168889               28

# %%
y_pred = grid_search.predict(X_test)

# %%
rf_vil = pd.DataFrame(list(zip(df.columns[:-1],best_model.feature_importances_)),
             columns=["feature","importance"]
            ).set_index("feature")
rf_vil.sort_values("importance",ascending=False)
# Out:
#                                 importance
# feature
# family_history_with_overweight    0.235909
# FCVC                              0.151362
# Age                               0.133724
# TUE                               0.106177
# CAEC                              0.098655
# FAF                               0.062770
# Gender                            0.055950
# NCP                               0.049462
# MTRANS                            0.035333
# CH2O                              0.028884
# CALC                              0.028096
# FAVC                              0.008160
# SCC                               0.004242
# SMOKE                             0.001275

# %%
cv_regression_report = compute_metrics(y_test, y_pred)
cv_regression_report
# Out:
# {'mae': np.float64(0.6208406219033903),
#  'rmse': np.float64(0.9536472475157545),
#  'r2': 0.9864773148456126}

# %%
from sklearn.tree import plot_tree

# %%
rf_tree = best_model.estimators_[-3]

# %%
plt.figure(figsize = (20,10))
plot_tree( # Función que nos permite visualizar el árbol de decisión ajustado.
    rf_tree, # Objeto de nuestro árbol de decisión entrenado.
    feature_names = list(X.columns), # Nombres de las variables utilizadas para entrenar.
    class_names = ["healthy","sick"], # Nombre de las clases que estamos prediciendo.
    label = "all", # Etiquetamos todas características de cada nodo.
    proportion = True, # Visualizamos las proporciones de datos en cada nodo de decisión,
    filled=True, # Coloreamos los nodos
    fontsize=11, # Establecemos el tamaño de la letra del texto dentro de cada nodo.,
    max_depth=3 # Profundidad máxima del árbol
    )
plt.show()

# %%
performances = pd.DataFrame( # Consolidamos todas las métricas en un DatFrame
    data = [
        lr_regression_report,
        cv_regression_report
    ],
    index = [
        "Linear Regression",
        "Grilla RF"
    ]
).sort_values( # Ordenamos los valores
   by="rmse"
)
performances
# Out:
#                         mae      rmse        r2
# Grilla RF          0.620841  0.953647  0.986477
# Linear Regression  4.853362  5.962436  0.471391

# %%
# Definir los modelos que deseas evaluar
models = [
    
    {
        'model': RandomForestRegressor(),
        'param_grid': {
            'n_estimators': [50, 100],
            'max_depth': [ 10, 20],
        }
    },
    {
        'model': LinearRegression(),
        'param_grid': {
            'fit_intercept': [True, False]
                   }
    }
]


# Realizar la búsqueda de hiperparámetros y validación cruzada para cada modelo
for model_info in models:
    model = model_info['model']
    param_grid = model_info['param_grid']
    
    grid_search_v2 = GridSearchCV(model, param_grid, cv=5)
    grid_search_v2.fit(X, y)

    print("Model:", model)
    print("Best Parameters:", grid_search_v2.best_params_)
    print("Best Score:", grid_search_v2.best_score_)
    print("--------------------------------------")
# Out:
# Model: RandomForestRegressor()
# Best Parameters: {'max_depth': 20, 'n_estimators': 100}
# Best Score: -1.7259170937082673
# --------------------------------------
# Model: LinearRegression()
# Best Parameters: {'fit_intercept': False}
# Best Score: -5.256519533198732
# --------------------------------------
